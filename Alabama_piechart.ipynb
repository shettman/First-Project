# %%
# %matplotlib notebook

# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Store filepath in a variable
file1 = "Resources/incidencepercapita.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
file1_df = pd.read_csv(file1, encoding="ISO-8859-1")

# %%
# Show just the header
file1_df.head()
# Out:
#    Unnamed: 0  state_name  Hepatitis A incidence_per_capita  \
# 0           0     ALABAMA                          0.140114
# 1           1      ALASKA                          1.666455
# 2           2     ARIZONA                          0.708678
# 3           3    ARKANSAS                          0.267547
# 4           4  CALIFORNIA                          0.584363
#
#    measles incidence_per_capita  mumps incidence_per_capita  \
# 0                      7.358485                    0.472036
# 1                      8.111158                    0.498955
# 2                      7.872509                    0.426592
# 3                      8.758858                    0.495492
# 4                      7.780177                    0.462301
#
#    pertussis incidence_per_capita  polio incidence_per_capita  \
# 0                        1.684924                    0.144214
# 1                        1.528616                    0.167105
# 2                        1.565009                    0.164784
# 3                        1.666336                    0.148262
# 4                        1.579469                    0.171283
#
#    rubella incidence_per_capita  smallpox incidence_per_capita
# 0                      0.264848                       0.264110
# 1                      0.213898                       0.238333
# 2                      0.208534                       0.230800
# 3                      0.204926                       0.217637
# 4                      0.235062                       0.265513

# %%
# Labels for the sections of our pie chart
labels = ["Hepatitis A incidence_per_capita", "measles incidence_per_capita", "mumps incidence_per_capita", "pertussis incidence_per_capita"]

# The values of each section of the pie chart for Alabama
sizes = [0.140114, 7.358485, 0.472036, 1.684924]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above for California
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x21fd35aa198>,
#   <matplotlib.patches.Wedge at 0x21fd35aab38>,
#   <matplotlib.patches.Wedge at 0x21fd35ba518>,
#   <matplotlib.patches.Wedge at 0x21fd35baeb8>],
#  [Text(-0.054687084958510816, 1.1987532368001101, 'Hepatitis A incidence_per_capita'),
#   Text(-0.67113308795576, -0.8715390858997468, 'measles incidence_per_capita'),
#   Text(1.0438895748288506, 0.34683505526927594, 'mumps incidence_per_capita'),
#   Text(0.5732827617697108, 0.9388007643039568, 'pertussis incidence_per_capita')],
#  [Text(-0.031900799559131304, 0.6992727214667308, '1.5%'),
#   Text(-0.36607259343041454, -0.4753849559453164, '76.2%'),
#   Text(0.5693943135430093, 0.18918275741960502, '4.9%'),
#   Text(0.312699688238024, 0.5120731441657945, '17.5%')])

# %%
# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")
# Out:
# (-1.1018336264153759,
#  1.1047516505993202,
#  -1.1092975206936582,
#  1.2050957994362155)
